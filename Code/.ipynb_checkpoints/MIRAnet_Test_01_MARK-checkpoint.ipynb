# %%
import os   # for path operations
import datetime

import tensorflow as tf
from tensorflow.python.client import device_lib

import numpy as np
import pandas as pd
import sklearn as sk
from sklearn import preprocessing

from keras.models import Sequential
from keras.layers.core import Activation, Dense, Flatten
from keras.optimizers import SGD
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.backend.tensorflow_backend import set_session
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config))
# Device check
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6498584312732839924
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 9202108990
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16317048789427814979
# physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
patience=40
early_stopping=EarlyStopping(patience=patience, verbose=1)
checkpointer=ModelCheckpoint(filepath="weights.hdf5", save_best_only=True, verbose =1)

# %%
def make_1d_convnet(window_size, filter_length, nb_input_series=1, nb_outputs=1,nb_filter=4):
    model = Sequential()
    model.add(Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu', 
                   input_shape=(window_size,nb_input_series)))
    model.add(MaxPooling1D())
    model.add(Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu'))
    model.add(MaxPooling1D())
    model.add(Flatten())
    model.add(Dense(nb_outputs,activation='linear'))
    model.compile(loss='mse', optimizer='adam', metrics=['mae'])
    return model

# %%
def make_timeseries_instances(timeseries,window_size,nb_inputs):
    timeseries = np.asarray(timeseries)
    assert 0 < window_size < timeseries.shape[0] , "Out of range 0 < {} < {}".format(window_size,timeseries.shape[0])
    X = np.atleast_3d(np.array([timeseries[start:start+window_size,:nb_inputs] for start in range(0,timeseries.shape[0]-window_size)]))
    #y = timeseries[window_size:,nb_inputs:]
    y = timeseries[window_size:,-9:-6]
    return X,y

# %%
def evalute_timeseries(timeseries, window_size, filter_length, nb_filter ):
    #timeseries = np.atleast_2d(timeseries)
    if timeseries.shape[0] == 1:
        timeseries = timeseries.T
    nb_samples, nb_series = timeseries.shape
    nb_inputs = nb_series - 6 #only 12 inputs
    #nb_outputs = nb_series - 9 #only 9 outputs
    nb_outputs=3
  
    model= make_1d_convnet(window_size=window_size, filter_length=filter_length, nb_input_series=nb_inputs,
                        nb_outputs=nb_outputs,nb_filter=nb_filter)
    model.summary()
  
    X,y = make_timeseries_instances(timeseries, window_size,nb_inputs=nb_inputs)
  
    test_size = int(0.3  * nb_samples)
    valid_size = int(0.2 * nb_samples)
    X_train, X_valid, X_test = X[:-(test_size+valid_size),:], X[-(test_size+valid_size):-test_size,:], X[-test_size:,:]
    y_train, y_valid, y_test = y[:-(test_size+valid_size),:], y[-(test_size+valid_size):-test_size,:], y[-test_size:,:]
    
    for inpt in range(X.shape[1]):
        scaler = preprocessing.StandardScaler().fit(X_train[:,inpt])
        X_train[:,inpt] = scaler.transform(X_train[:,inpt])
        X_valid[:,inpt] = scaler.transform(X_valid[:,inpt])
        X_test[:,inpt] = scaler.transform(X_test[:,inpt])
    
    model.fit(X_train,y_train, epochs = 100, batch_size = 16, validation_data = (X_valid, y_valid),
              verbose = 2, callbacks = [checkpointer,early_stopping])
  
    preds=model.predict(X_test)
    targets = y_test
    
    print(preds.shape)
    print(targets.shape)
    
    plt.figure(0)
    plt.plot(preds[:,0],color='green')
    plt.plot(targets[:,0],color='red')
    
    plt.figure(1)
    plt.plot(preds[:,2],color='blue')
    plt.plot(targets[:,2],color='yellow')
    
    plt.figure(2)
    plt.plot(preds[:,0],preds[:,2])
    plt.plot(targets[:,0],targets[:,2])

# %% [markdown]
# # Load Data

# %%
lock_meas = '..\\DATA\\RAW\\Measure_02'
file_list = os.listdir(lock_meas)
nb_meas = len(file_list)/4
print("Number of Measurements: %0.f" % nb_meas)
# Out:
# Number of Measurements: 6

# %%
meas_list = []
for FILE_NAME in file_list:
    meas_list.append(FILE_NAME[0:22])
meas_list = list(set(meas_list))

# %%
# Load in one favourite measurement block
meas_id = 4
print(str(meas_list[meas_id]))

if meas_id>(nb_meas-1):
    print('Error: Out of range. Meas_id set to default 0')
    meas = 0
meas_date = str(meas_list[meas_id])

imu_data = pd.read_csv(lock_meas + '\\' + meas_date + 'IMU.txt',
                               sep='\t',
                               decimal=',',
                               names=['time', 'acc0', 'acc1', 'acc2', 'gyro0', 'gyro1', 'gyro2', 'mag0', 'mag1', 'mag2'])

mocap_data = pd.read_csv(lock_meas + '\\' + meas_date + 'MoCap.txt',
                                 sep='\t',
                                 decimal=',',
                                 names=['time', 'x', 'y', 'z', 'tracked', 'beta', 'Qx', 'Qy', 'Qz', 'Qw'])
# Out:
# 2018_ 10_ 19_18_06_14_

# %%
imu_data.head(5)
# Out:
#           time   acc0   acc1   acc2  gyro0  gyro1  gyro2   mag0   mag1   mag2
# 0  180614.4063  0.005 -0.052  1.025 -0.745  0.201 -0.121  0.000  0.000  0.000
# 1  180614.4153  0.006 -0.052  1.025 -0.786  0.322 -0.215  0.000  0.000  0.000
# 2  180614.4243  0.005 -0.052  1.026 -0.705  0.121  0.013 -0.333 -0.282  0.048
# 3  180614.4332  0.005 -0.051  1.026 -0.967  0.000 -0.134 -0.333 -0.282  0.048
# 4  180614.4422  0.004 -0.051  1.026 -0.806  0.262  0.121 -0.333 -0.282  0.048

# %%
mocap_data.head(5)
# Out:
#           time      x      y      z  tracked   beta     Qx     Qy     Qz   Qw
# 0  180614.4063 -0.485  0.222 -0.468      1.0  2.877  0.014 -0.025  0.005  1.0
# 1  180614.4153 -0.485  0.222 -0.468      1.0  2.874  0.014 -0.025  0.005  1.0
# 2  180614.4243 -0.485  0.222 -0.468      1.0  2.868  0.014 -0.025  0.005  1.0
# 3  180614.4332 -0.485  0.222 -0.468      1.0  2.866  0.014 -0.025  0.005  1.0
# 4  180614.4422 -0.485  0.222 -0.468      1.0  2.869  0.014 -0.025  0.005  1.0

# %%
data = pd.merge(imu_data, mocap_data, on=['time'], how='inner')
len(data)
# Out:
# 12788

# %%
data.head()
# Out:
#           time   acc0   acc1   acc2  gyro0  gyro1  gyro2   mag0   mag1   mag2  \
# 0  180614.4063  0.005 -0.052  1.025 -0.745  0.201 -0.121  0.000  0.000  0.000
# 1  180614.4153  0.006 -0.052  1.025 -0.786  0.322 -0.215  0.000  0.000  0.000
# 2  180614.4243  0.005 -0.052  1.026 -0.705  0.121  0.013 -0.333 -0.282  0.048
# 3  180614.4332  0.005 -0.051  1.026 -0.967  0.000 -0.134 -0.333 -0.282  0.048
# 4  180614.4422  0.004 -0.051  1.026 -0.806  0.262  0.121 -0.333 -0.282  0.048
#
#        x      y      z  tracked   beta     Qx     Qy     Qz   Qw
# 0 -0.485  0.222 -0.468      1.0  2.877  0.014 -0.025  0.005  1.0
# 1 -0.485  0.222 -0.468      1.0  2.874  0.014 -0.025  0.005  1.0
# 2 -0.485  0.222 -0.468      1.0  2.868  0.014 -0.025  0.005  1.0
# 3 -0.485  0.222 -0.468      1.0  2.866  0.014 -0.025  0.005  1.0
# 4 -0.485  0.222 -0.468      1.0  2.869  0.014 -0.025  0.005  1.0

# %%
#1D convolution
window_size = 20
filter_length = 5
nb_filter = 4

#Train config
epochs = 50
batch_size = 16
validation_split = 0.2

# %%
print(data.shape)
timeData=np.array(data)
timeData=np.delete(timeData,0,1)
print(timeData.shape)
# Out:
# (12788, 19)
# (12788, 18)

# %%
evalute_timeseries(timeData,window_size,filter_length,nb_filter)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 16, 4)             244
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 8, 4)              0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 4, 4)              84
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 2, 4)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 355
# Trainable params: 355
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6375 samples, validate on 2557 samples
# Epoch 1/100
#  - 2s - loss: 0.2358 - mean_absolute_error: 0.3029 - val_loss: 0.1959 - val_mean_absolute_error: 0.3227
#
# Epoch 00001: val_loss improved from inf to 0.19591, saving model to weights.hdf5
# Epoch 2/100
#  - 1s - loss: 0.0409 - mean_absolute_error: 0.1382 - val_loss: 0.0947 - val_mean_absolute_error: 0.2151
#
# Epoch 00002: val_loss improved from 0.19591 to 0.09473, saving model to weights.hdf5
# Epoch 3/100
#  - 1s - loss: 0.0167 - mean_absolute_error: 0.0871 - val_loss: 0.0517 - val_mean_absolute_error: 0.1569
#
# Epoch 00003: val_loss improved from 0.09473 to 0.05174, saving model to weights.hdf5
# Epoch 4/100
#  - 1s - loss: 0.0088 - mean_absolute_error: 0.0623 - val_loss: 0.0401 - val_mean_absolute_error: 0.1400
#
# Epoch 00004: val_loss improved from 0.05174 to 0.04009, saving model to weights.hdf5
# Epoch 5/100
#  - 1s - loss: 0.0052 - mean_absolute_error: 0.0475 - val_loss: 0.0349 - val_mean_absolute_error: 0.1302
#
# Epoch 00005: val_loss improved from 0.04009 to 0.03493, saving model to weights.hdf5
# Epoch 6/100
#  - 1s - loss: 0.0034 - mean_absolute_error: 0.0380 - val_loss: 0.0354 - val_mean_absolute_error: 0.1326
#
# Epoch 00006: val_loss did not improve from 0.03493
# Epoch 7/100
#  - 1s - loss: 0.0024 - mean_absolute_error: 0.0315 - val_loss: 0.0343 - val_mean_absolute_error: 0.1317
#
# Epoch 00007: val_loss improved from 0.03493 to 0.03430, saving model to weights.hdf5
# Epoch 8/100
#  - 1s - loss: 0.0018 - mean_absolute_error: 0.0269 - val_loss: 0.0359 - val_mean_absolute_error: 0.1379
#
# Epoch 00008: val_loss did not improve from 0.03430
# Epoch 9/100
#  - 1s - loss: 0.0015 - mean_absolute_error: 0.0236 - val_loss: 0.0327 - val_mean_absolute_error: 0.1313
#
# Epoch 00009: val_loss improved from 0.03430 to 0.03269, saving model to weights.hdf5
# Epoch 10/100
#  - 1s - loss: 0.0012 - mean_absolute_error: 0.0211 - val_loss: 0.0360 - val_mean_absolute_error: 0.1395
#
# Epoch 00010: val_loss did not improve from 0.03269
# Epoch 11/100
#  - 1s - loss: 0.0010 - mean_absolute_error: 0.0188 - val_loss: 0.0344 - val_mean_absolute_error: 0.1353
#
# Epoch 00011: val_loss did not improve from 0.03269
# Epoch 12/100
#  - 1s - loss: 9.0289e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0336 - val_mean_absolute_error: 0.1329
#
# Epoch 00012: val_loss did not improve from 0.03269
# Epoch 13/100
#  - 1s - loss: 7.8776e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0353 - val_mean_absolute_error: 0.1362
#
# Epoch 00013: val_loss did not improve from 0.03269
# Epoch 14/100
#  - 1s - loss: 6.7580e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0367 - val_mean_absolute_error: 0.1390
#
# Epoch 00014: val_loss did not improve from 0.03269
# Epoch 15/100
#  - 1s - loss: 6.4567e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0355 - val_mean_absolute_error: 0.1360
#
# Epoch 00015: val_loss did not improve from 0.03269
# Epoch 16/100
#  - 1s - loss: 5.7366e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0342 - val_mean_absolute_error: 0.1323
#
# Epoch 00016: val_loss did not improve from 0.03269
# Epoch 17/100
#  - 1s - loss: 5.2133e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0338 - val_mean_absolute_error: 0.1312
#
# Epoch 00017: val_loss did not improve from 0.03269
# Epoch 18/100
#  - 1s - loss: 4.8410e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0320 - val_mean_absolute_error: 0.1268
#
# Epoch 00018: val_loss improved from 0.03269 to 0.03202, saving model to weights.hdf5
# Epoch 19/100
#  - 1s - loss: 4.5295e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0293 - val_mean_absolute_error: 0.1196
#
# Epoch 00019: val_loss improved from 0.03202 to 0.02934, saving model to weights.hdf5
# Epoch 20/100
#  - 1s - loss: 3.9504e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0274 - val_mean_absolute_error: 0.1150
#
# Epoch 00020: val_loss improved from 0.02934 to 0.02743, saving model to weights.hdf5
# Epoch 21/100
#  - 1s - loss: 3.9496e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0272 - val_mean_absolute_error: 0.1146
#
# Epoch 00021: val_loss improved from 0.02743 to 0.02720, saving model to weights.hdf5
# Epoch 22/100
#  - 1s - loss: 3.8380e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0241 - val_mean_absolute_error: 0.1053
#
# Epoch 00022: val_loss improved from 0.02720 to 0.02408, saving model to weights.hdf5
# Epoch 23/100
#  - 1s - loss: 3.4839e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0234 - val_mean_absolute_error: 0.1029
#
# Epoch 00023: val_loss improved from 0.02408 to 0.02337, saving model to weights.hdf5
# Epoch 24/100
#  - 1s - loss: 3.3732e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0225 - val_mean_absolute_error: 0.1004
#
# Epoch 00024: val_loss improved from 0.02337 to 0.02247, saving model to weights.hdf5
# Epoch 25/100
#  - 1s - loss: 2.9626e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0214 - val_mean_absolute_error: 0.0974
#
# Epoch 00025: val_loss improved from 0.02247 to 0.02135, saving model to weights.hdf5
# Epoch 26/100
#  - 1s - loss: 2.9786e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0205 - val_mean_absolute_error: 0.0951
#
# Epoch 00026: val_loss improved from 0.02135 to 0.02049, saving model to weights.hdf5
# Epoch 27/100
#  - 1s - loss: 2.6922e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0204 - val_mean_absolute_error: 0.0949
#
# Epoch 00027: val_loss improved from 0.02049 to 0.02045, saving model to weights.hdf5
# Epoch 28/100
#  - 1s - loss: 2.5947e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0205 - val_mean_absolute_error: 0.0949
#
# Epoch 00028: val_loss did not improve from 0.02045
# Epoch 29/100
#  - 1s - loss: 2.6371e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0191 - val_mean_absolute_error: 0.0913
#
# Epoch 00029: val_loss improved from 0.02045 to 0.01913, saving model to weights.hdf5
# Epoch 30/100
#  - 1s - loss: 2.5628e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0191 - val_mean_absolute_error: 0.0912
#
# Epoch 00030: val_loss improved from 0.01913 to 0.01910, saving model to weights.hdf5
# Epoch 31/100
#  - 1s - loss: 2.5371e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0193 - val_mean_absolute_error: 0.0928
#
# Epoch 00031: val_loss did not improve from 0.01910
# Epoch 32/100
#  - 1s - loss: 2.4541e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0208 - val_mean_absolute_error: 0.0950
#
# Epoch 00032: val_loss did not improve from 0.01910
# Epoch 33/100
#  - 1s - loss: 2.2804e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0218 - val_mean_absolute_error: 0.0972
#
# Epoch 00033: val_loss did not improve from 0.01910
# Epoch 34/100
#  - 1s - loss: 2.3051e-04 - mean_absolute_error: 0.0066 - val_loss: 0.0231 - val_mean_absolute_error: 0.0998
#
# Epoch 00034: val_loss did not improve from 0.01910
# Epoch 35/100
#  - 1s - loss: 2.3572e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0251 - val_mean_absolute_error: 0.1034
#
# Epoch 00035: val_loss did not improve from 0.01910
# Epoch 36/100
#  - 1s - loss: 2.1267e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0277 - val_mean_absolute_error: 0.1083
#
# Epoch 00036: val_loss did not improve from 0.01910
# Epoch 37/100
#  - 1s - loss: 2.5250e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0282 - val_mean_absolute_error: 0.1097
#
# Epoch 00037: val_loss did not improve from 0.01910
# Epoch 38/100
#  - 1s - loss: 2.0330e-04 - mean_absolute_error: 0.0060 - val_loss: 0.0319 - val_mean_absolute_error: 0.1164
# Epoch 00038: val_loss did not improve from 0.01910
# Epoch 39/100
#  - 1s - loss: 2.1853e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0339 - val_mean_absolute_error: 0.1212
#
# Epoch 00039: val_loss did not improve from 0.01910
# Epoch 40/100
#  - 1s - loss: 2.1521e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0333 - val_mean_absolute_error: 0.1183
#
# Epoch 00040: val_loss did not improve from 0.01910
# Epoch 41/100
#  - 1s - loss: 1.9840e-04 - mean_absolute_error: 0.0061 - val_loss: 0.0388 - val_mean_absolute_error: 0.1278
#
# Epoch 00041: val_loss did not improve from 0.01910
# Epoch 42/100
#  - 1s - loss: 2.0849e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0420 - val_mean_absolute_error: 0.1320
#
# Epoch 00042: val_loss did not improve from 0.01910
# Epoch 43/100
#  - 1s - loss: 1.9215e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0458 - val_mean_absolute_error: 0.1370
#
# Epoch 00043: val_loss did not improve from 0.01910
# Epoch 44/100
#  - 1s - loss: 1.8447e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0484 - val_mean_absolute_error: 0.1414
#
# Epoch 00044: val_loss did not improve from 0.01910
# Epoch 45/100
#  - 1s - loss: 2.0661e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0489 - val_mean_absolute_error: 0.1437
#
# Epoch 00045: val_loss did not improve from 0.01910
# Epoch 46/100
#  - 1s - loss: 2.3397e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0503 - val_mean_absolute_error: 0.1444
#
# Epoch 00046: val_loss did not improve from 0.01910
# Epoch 47/100
#  - 1s - loss: 1.7507e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0513 - val_mean_absolute_error: 0.1455
#
# Epoch 00047: val_loss did not improve from 0.01910
# Epoch 48/100
#  - 1s - loss: 1.6068e-04 - mean_absolute_error: 0.0052 - val_loss: 0.0536 - val_mean_absolute_error: 0.1482
#
# Epoch 00048: val_loss did not improve from 0.01910
# Epoch 49/100
#  - 1s - loss: 1.8222e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0550 - val_mean_absolute_error: 0.1503
#
# Epoch 00049: val_loss did not improve from 0.01910
# Epoch 50/100
#  - 1s - loss: 1.7073e-04 - mean_absolute_error: 0.0055 - val_loss: 0.0567 - val_mean_absolute_error: 0.1525
#
# Epoch 00050: val_loss did not improve from 0.01910
# Epoch 51/100
#  - 1s - loss: 1.7635e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0574 - val_mean_absolute_error: 0.1534
#
# Epoch 00051: val_loss did not improve from 0.01910
# Epoch 52/100
#  - 1s - loss: 1.8322e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0615 - val_mean_absolute_error: 0.1587
#
# Epoch 00052: val_loss did not improve from 0.01910
# Epoch 53/100
#  - 1s - loss: 1.6242e-04 - mean_absolute_error: 0.0055 - val_loss: 0.0588 - val_mean_absolute_error: 0.1553
#
# Epoch 00053: val_loss did not improve from 0.01910
# Epoch 54/100
#  - 1s - loss: 1.7697e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0626 - val_mean_absolute_error: 0.1594
#
# Epoch 00054: val_loss did not improve from 0.01910
# Epoch 55/100
#  - 1s - loss: 1.9616e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0679 - val_mean_absolute_error: 0.1664
#
# Epoch 00055: val_loss did not improve from 0.01910
# Epoch 56/100
#  - 1s - loss: 1.9478e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0669 - val_mean_absolute_error: 0.1645
#
# Epoch 00056: val_loss did not improve from 0.01910
# Epoch 57/100
#  - 1s - loss: 1.5165e-04 - mean_absolute_error: 0.0050 - val_loss: 0.0670 - val_mean_absolute_error: 0.1648
#
# Epoch 00057: val_loss did not improve from 0.01910
# Epoch 58/100
#  - 1s - loss: 1.5950e-04 - mean_absolute_error: 0.0054 - val_loss: 0.0669 - val_mean_absolute_error: 0.1638
#
# Epoch 00058: val_loss did not improve from 0.01910
# Epoch 59/100
#  - 1s - loss: 1.5472e-04 - mean_absolute_error: 0.0054 - val_loss: 0.0731 - val_mean_absolute_error: 0.1724
#
# Epoch 00059: val_loss did not improve from 0.01910
# Epoch 60/100
#  - 1s - loss: 1.5320e-04 - mean_absolute_error: 0.0054 - val_loss: 0.0701 - val_mean_absolute_error: 0.1683
#
# Epoch 00060: val_loss did not improve from 0.01910
# Epoch 61/100
#  - 1s - loss: 1.4557e-04 - mean_absolute_error: 0.0052 - val_loss: 0.0694 - val_mean_absolute_error: 0.1679
#
# Epoch 00061: val_loss did not improve from 0.01910
# Epoch 62/100
#  - 1s - loss: 1.9654e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0708 - val_mean_absolute_error: 0.1688
#
# Epoch 00062: val_loss did not improve from 0.01910
# Epoch 63/100
#  - 1s - loss: 1.4983e-04 - mean_absolute_error: 0.0054 - val_loss: 0.0693 - val_mean_absolute_error: 0.1677
#
# Epoch 00063: val_loss did not improve from 0.01910
# Epoch 64/100
#  - 1s - loss: 1.3779e-04 - mean_absolute_error: 0.0050 - val_loss: 0.0694 - val_mean_absolute_error: 0.1685
#
# Epoch 00064: val_loss did not improve from 0.01910
# Epoch 65/100
#  - 1s - loss: 1.5611e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0691 - val_mean_absolute_error: 0.1690
#
# Epoch 00065: val_loss did not improve from 0.01910
# Epoch 66/100
#  - 1s - loss: 1.4631e-04 - mean_absolute_error: 0.0054 - val_loss: 0.0682 - val_mean_absolute_error: 0.1668
#
# Epoch 00066: val_loss did not improve from 0.01910
# Epoch 67/100
#  - 1s - loss: 1.2747e-04 - mean_absolute_error: 0.0046 - val_loss: 0.0744 - val_mean_absolute_error: 0.1760
#
# Epoch 00067: val_loss did not improve from 0.01910
# Epoch 68/100
#  - 1s - loss: 1.7470e-04 - mean_absolute_error: 0.0060 - val_loss: 0.0752 - val_mean_absolute_error: 0.1757
#
# Epoch 00068: val_loss did not improve from 0.01910
# Epoch 69/100
#  - 1s - loss: 1.6756e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0768 - val_mean_absolute_error: 0.1776
#
# Epoch 00069: val_loss did not improve from 0.01910
# Epoch 70/100
#  - 1s - loss: 1.3390e-04 - mean_absolute_error: 0.0049 - val_loss: 0.0767 - val_mean_absolute_error: 0.1767
#
# Epoch 00070: val_loss did not improve from 0.01910
# Epoch 00070: early stopping
# (3836, 3)
# (3836, 3)

# %%
plt.plot(timeData[:,-9],timeData[:,-7])
