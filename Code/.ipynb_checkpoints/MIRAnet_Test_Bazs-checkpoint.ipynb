# %% [markdown]
# DimensionPatch

# %%
import os   # for path operations
import datetime

import tensorflow as tf
from tensorflow.python.client import device_lib

import numpy as np
import pandas as pd
import sklearn as sk
from sklearn import preprocessing

from keras.models import Sequential
from keras.layers.core import Activation, Dense, Flatten
from keras.optimizers import SGD
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.backend.tensorflow_backend import set_session

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config))
# Device check
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4701010044004510960
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3168377241
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14038803873083492393
# physical_device_desc: "device: 0, name: GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
# nb_input_series : time + 9 IMU data + optional prev. beta (min 10)
# nb_outputs : beta () or quvaternion representation) (min 1)

def make_1d_convnet(window_size, filter_length, nb_input_series=1, nb_outputs=1,nb_filter=4):
  model = Sequential()
  model.add(Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu', 
                   input_shape=(window_size,nb_input_series)))
  model.add(MaxPooling1D())
  model.add(Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu'))
  model.add(MaxPooling1D())
  model.add(Flatten())
  model.add(Dense(nb_outputs,activation='linear'))
  model.compile(loss='mse', optimizer='adam', metrics=['mae'])
  return model

# %%
def make_timeseries_instances(timeseries,window_size):
  timeseries = np.asarray(timeseries)
  assert 0 < window_size < timeseries.shape[0] , "Out of range 0 < {} < {}".format(window_size,timeseries.shape[0])
  X = np.atleast_3d(np.array([timeseries[start:start+window_size] for start in range(0,timeseries.shape[0]-window_size)]))
  y = timeseries[window_size:]
  return X,y

# %%
def evalute_timeseries(X, Y, window_size, filter_length, nb_filter, valid_split, test_split):
  nb_samples = X.shape[0]
  nb_series = X.shape[2]
  
  # Model definition (previously definied) 10 input chanel, 1 output chanel
  model= make_1d_convnet(window_size=window_size, filter_length=filter_length, nb_input_series=nb_series,
                        nb_outputs=1,nb_filter=nb_filter)
  model.summary()
    
  valid_size = int(nb_samples*(1-test_split-valid_split))
  test_size = int(nb_samples*(1-test_split))
  X_train, Y_train = X[:valid_size], Y[:valid_size]
  X_valid, Y_valid = X[valid_size:test_size], Y[valid_size:test_size]
  X_test, Y_test   = X[test_size:], Y[test_size:]
    
  model.fit(X_train, Y_train, epochs=50, batch_size=16, validation_data=(X_valid, Y_valid), verbose=2)
    
  preds=model.predict(X_test)
  targets = Y_test

  plt.plot(preds)
  plt.plot(targets)
  return preds, targets

# %%
# Out:
# 12768

# %% [markdown]
# # Load Data

# %%
lock_meas = '..\\DATA\\RAW\\Measure_02'
file_list = os.listdir(lock_meas)
nb_meas = len(file_list)/4
print("Number of Measurements: %0.f" % nb_meas)
# Out:
# Number of Measurements: 6

# %%
meas_list = []
for FILE_NAME in file_list:
    meas_list.append(FILE_NAME[0:22])
meas_list = list(set(meas_list))

# %%
# Load in one favourite measurement block
meas_id = 0
print(str(meas_list[meas_id]))

if meas_id>(nb_meas-1):
    print('Error: Out of range. Meas_id set to default 0')
    meas = 0
meas_date = str(meas_list[meas_id])

imu_data = pd.read_csv(lock_meas + '\\' + meas_date + 'IMU.txt',
                               sep='\t',
                               decimal=',',
                               names=['time', 'acc0', 'acc1', 'acc2', 'gyro0', 'gyro1', 'gyro2', 'mag0', 'mag1', 'mag2'])

mocap_data = pd.read_csv(lock_meas + '\\' + meas_date + 'MoCap.txt',
                                 sep='\t',
                                 decimal=',',
                                 names=['time', 'x', 'y', 'z', 'tracked', 'beta', 'Qx', 'Qy', 'Qz', 'Qw'])
# Out:
# 2018_ 10_ 19_18_06_14_

# %%
imu_data.head(5)
# Out:
#           time   acc0   acc1   acc2  gyro0  gyro1  gyro2   mag0   mag1   mag2
# 0  180614.4063  0.005 -0.052  1.025 -0.745  0.201 -0.121  0.000  0.000  0.000
# 1  180614.4153  0.006 -0.052  1.025 -0.786  0.322 -0.215  0.000  0.000  0.000
# 2  180614.4243  0.005 -0.052  1.026 -0.705  0.121  0.013 -0.333 -0.282  0.048
# 3  180614.4332  0.005 -0.051  1.026 -0.967  0.000 -0.134 -0.333 -0.282  0.048
# 4  180614.4422  0.004 -0.051  1.026 -0.806  0.262  0.121 -0.333 -0.282  0.048

# %%
mocap_data.head(5)
# Out:
#           time      x      y      z  tracked   beta     Qx     Qy     Qz   Qw
# 0  180614.4063 -0.485  0.222 -0.468      1.0  2.877  0.014 -0.025  0.005  1.0
# 1  180614.4153 -0.485  0.222 -0.468      1.0  2.874  0.014 -0.025  0.005  1.0
# 2  180614.4243 -0.485  0.222 -0.468      1.0  2.868  0.014 -0.025  0.005  1.0
# 3  180614.4332 -0.485  0.222 -0.468      1.0  2.866  0.014 -0.025  0.005  1.0
# 4  180614.4422 -0.485  0.222 -0.468      1.0  2.869  0.014 -0.025  0.005  1.0

# %%
data = pd.merge(imu_data, mocap_data, on=['time'], how='inner')
len(data)
# Out:
# 12788

# %%
data.head()
# Out:
#           time   acc0   acc1   acc2  gyro0  gyro1  gyro2   mag0   mag1   mag2  \
# 0  180614.4063  0.005 -0.052  1.025 -0.745  0.201 -0.121  0.000  0.000  0.000
# 1  180614.4153  0.006 -0.052  1.025 -0.786  0.322 -0.215  0.000  0.000  0.000
# 2  180614.4243  0.005 -0.052  1.026 -0.705  0.121  0.013 -0.333 -0.282  0.048
# 3  180614.4332  0.005 -0.051  1.026 -0.967  0.000 -0.134 -0.333 -0.282  0.048
# 4  180614.4422  0.004 -0.051  1.026 -0.806  0.262  0.121 -0.333 -0.282  0.048
#
#        x      y      z  tracked   beta     Qx     Qy     Qz   Qw
# 0 -0.485  0.222 -0.468      1.0  2.877  0.014 -0.025  0.005  1.0
# 1 -0.485  0.222 -0.468      1.0  2.874  0.014 -0.025  0.005  1.0
# 2 -0.485  0.222 -0.468      1.0  2.868  0.014 -0.025  0.005  1.0
# 3 -0.485  0.222 -0.468      1.0  2.866  0.014 -0.025  0.005  1.0
# 4 -0.485  0.222 -0.468      1.0  2.869  0.014 -0.025  0.005  1.0

# %%
data.shape
# Out:
# (12788, 19)

# %%
f1, (ax1, ax2, ax3) = plt.subplots(3, 1)
data.plot(x='time', y='acc0', figsize=(15,10), ax=ax1)
data.plot(x='time', y='acc1', ax=ax1)
data.plot(x='time', y='acc2', ax=ax1)
data.plot(x='time', y='gyro0', ax=ax2)
data.plot(x='time', y='gyro1', ax=ax2)
data.plot(x='time', y='gyro2', ax=ax2)
data.plot(x='time', y='mag0', ax=ax3)
data.plot(x='time', y='mag1', ax=ax3)
data.plot(x='time', y='mag2', ax=ax3)

# %%
f2, (ax4, ax5, ax6, ax7) = plt.subplots(4, 1)
data.plot(x='time', y='x', figsize=(15,10), ax=ax4)
data.plot(x='time', y='y', ax=ax4)
data.plot(x='time', y='z', ax=ax4)
data.plot(x='time', y='tracked', ax=ax5)
data.plot(x='time', y='Qx', ax=ax6)
data.plot(x='time', y='Qy', ax=ax6)
data.plot(x='time', y='Qz', ax=ax6)
data.plot(x='time', y='Qw', ax=ax6)
data.plot(x='time', y='beta', ax=ax7)

# %%
data.plot(x='x', y='z', color='red', figsize=(15,15), label='MoCap')

# %%
#1D convolution
window_size = 20
filter_length = 5
nb_filter = 4

#Train config
epochs = 50
batch_size = 16
vs = 0.15
ts = 0.15

# %%
data.head(1)
# Out:
#           time   acc0   acc1   acc2  gyro0  gyro1  gyro2  mag0  mag1  mag2  \
# 0  180614.4063  0.005 -0.052  1.025 -0.745  0.201 -0.121   0.0   0.0   0.0
#
#        x      y      z  tracked   beta     Qx     Qy     Qz   Qw
# 0 -0.485  0.222 -0.468      1.0  2.877  0.014 -0.025  0.005  1.0

# %%
Y = np.array(data['x'][window_size:])
X= np.array(data[list(data.columns[0:9])])

# %%
X.shape
# Out:
# (12788, 9)

# %%
X = np.atleast_3d(np.array([X[start:start+window_size] for start in range(0,X.shape[0]-window_size)]))

# %%
X.shape
# Out:
# (12768, 20, 9)

# %%
pred, target = evalute_timeseries(X, Y, window_size,filter_length,nb_filter, vs, ts)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 16, 4)             184
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 8, 4)              0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 4, 4)              84
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 2, 4)              0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 8)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 277
# Trainable params: 277
# Non-trainable params: 0
# _________________________________________________________________
# Train on 8937 samples, validate on 1915 samples
# Epoch 1/50
#  - 3s - loss: 546434.9025 - mean_absolute_error: 162.1450 - val_loss: 44.9804 - val_mean_absolute_error: 5.3836
# Epoch 2/50
#  - 2s - loss: 22.5626 - mean_absolute_error: 3.5319 - val_loss: 18.8538 - val_mean_absolute_error: 3.5371
# Epoch 3/50
#  - 2s - loss: 8.9256 - mean_absolute_error: 2.3337 - val_loss: 6.8836 - val_mean_absolute_error: 2.0656
# Epoch 4/50
#  - 2s - loss: 2.8676 - mean_absolute_error: 1.3611 - val_loss: 2.0015 - val_mean_absolute_error: 1.1310
# Epoch 5/50
#  - 2s - loss: 1.4088 - mean_absolute_error: 0.9400 - val_loss: 1.3510 - val_mean_absolute_error: 0.8305
# Epoch 6/50
#  - 2s - loss: 1.3191 - mean_absolute_error: 0.8889 - val_loss: 1.4013 - val_mean_absolute_error: 0.8468
# Epoch 7/50
#  - 2s - loss: 1.3724 - mean_absolute_error: 0.9138 - val_loss: 1.2986 - val_mean_absolute_error: 0.8088
# Epoch 8/50
#  - 2s - loss: 1.4835 - mean_absolute_error: 0.9515 - val_loss: 4.8964 - val_mean_absolute_error: 2.0330
# Epoch 9/50
#  - 2s - loss: 2.0872 - mean_absolute_error: 1.1384 - val_loss: 1.6249 - val_mean_absolute_error: 0.9442
# Epoch 10/50
#  - 2s - loss: 2.9444 - mean_absolute_error: 1.3515 - val_loss: 2.1002 - val_mean_absolute_error: 1.2152
# Epoch 11/50
#  - 2s - loss: 4.6808 - mean_absolute_error: 1.7351 - val_loss: 1.1992 - val_mean_absolute_error: 0.7896
# Epoch 12/50
#  - 2s - loss: 310.9951 - mean_absolute_error: 11.3934 - val_loss: 145.7407 - val_mean_absolute_error: 12.0013
# Epoch 13/50
#  - 2s - loss: 433.4661 - mean_absolute_error: 15.4535 - val_loss: 1474.3762 - val_mean_absolute_error: 38.3826
# Epoch 14/50
#  - 2s - loss: 510.8676 - mean_absolute_error: 16.5868 - val_loss: 2593.2994 - val_mean_absolute_error: 50.9140
# Epoch 15/50
#  - 2s - loss: 398.6428 - mean_absolute_error: 14.4610 - val_loss: 922.6476 - val_mean_absolute_error: 30.3515
# Epoch 16/50
#  - 2s - loss: 381.7117 - mean_absolute_error: 13.7307 - val_loss: 80.8154 - val_mean_absolute_error: 8.9351
# Epoch 17/50
#  - 2s - loss: 393.4041 - mean_absolute_error: 14.5480 - val_loss: 340.6348 - val_mean_absolute_error: 18.4311
# Epoch 18/50
#  - 2s - loss: 349.6427 - mean_absolute_error: 12.8400 - val_loss: 13.1628 - val_mean_absolute_error: 3.4873
# Epoch 19/50
#  - 2s - loss: 315.0079 - mean_absolute_error: 14.3221 - val_loss: 812.1926 - val_mean_absolute_error: 28.4832
# Epoch 20/50
#  - 2s - loss: 314.8422 - mean_absolute_error: 13.8130 - val_loss: 38.6063 - val_mean_absolute_error: 6.1405
# Epoch 21/50
#  - 2s - loss: 274.6971 - mean_absolute_error: 13.4204 - val_loss: 786.8116 - val_mean_absolute_error: 28.0285
# Epoch 22/50
#  - 2s - loss: 280.9583 - mean_absolute_error: 12.6095 - val_loss: 36.6326 - val_mean_absolute_error: 5.9802
# Epoch 23/50
#  - 2s - loss: 244.0495 - mean_absolute_error: 10.7311 - val_loss: 250.6923 - val_mean_absolute_error: 15.8054
# Epoch 24/50
#  - 2s - loss: 238.5437 - mean_absolute_error: 11.0825 - val_loss: 3.8749 - val_mean_absolute_error: 1.8070
# Epoch 25/50
#  - 2s - loss: 230.7886 - mean_absolute_error: 11.0781 - val_loss: 10.3554 - val_mean_absolute_error: 3.0459
# Epoch 26/50
#  - 2s - loss: 145.1422 - mean_absolute_error: 9.0044 - val_loss: 219.8154 - val_mean_absolute_error: 14.8010
# Epoch 27/50
#  - 2s - loss: 192.0036 - mean_absolute_error: 10.4717 - val_loss: 1.6621 - val_mean_absolute_error: 1.0735
# Epoch 28/50
#  - 2s - loss: 153.2668 - mean_absolute_error: 8.1297 - val_loss: 13.0736 - val_mean_absolute_error: 3.5130
# Epoch 29/50
#  - 2s - loss: 126.2931 - mean_absolute_error: 8.5462 - val_loss: 26.8348 - val_mean_absolute_error: 5.1110
# Epoch 30/50
#  - 2s - loss: 128.8654 - mean_absolute_error: 8.9190 - val_loss: 50.6830 - val_mean_absolute_error: 7.0653
# Epoch 31/50
#  - 2s - loss: 108.0196 - mean_absolute_error: 7.6191 - val_loss: 30.6624 - val_mean_absolute_error: 5.4716
# Epoch 32/50
#  - 2s - loss: 85.7895 - mean_absolute_error: 7.1008 - val_loss: 137.3841 - val_mean_absolute_error: 11.6909
# Epoch 33/50
#  - 2s - loss: 77.1520 - mean_absolute_error: 6.7908 - val_loss: 10.9694 - val_mean_absolute_error: 3.2073
# Epoch 34/50
#  - 2s - loss: 61.2303 - mean_absolute_error: 5.7343 - val_loss: 145.9481 - val_mean_absolute_error: 12.0515
# Epoch 35/50
#  - 2s - loss: 54.9939 - mean_absolute_error: 5.8055 - val_loss: 6.5369 - val_mean_absolute_error: 2.4251
# Epoch 36/50
#  - 2s - loss: 40.7351 - mean_absolute_error: 5.1384 - val_loss: 90.8488 - val_mean_absolute_error: 9.4912
# Epoch 37/50
#  - 2s - loss: 34.4814 - mean_absolute_error: 4.9212 - val_loss: 10.4627 - val_mean_absolute_error: 3.1302
# Epoch 38/50
#  - 2s - loss: 25.3606 - mean_absolute_error: 4.0319 - val_loss: 31.0334 - val_mean_absolute_error: 5.5114
# Epoch 39/50
#  - 2s - loss: 20.6765 - mean_absolute_error: 3.5615 - val_loss: 1.0640 - val_mean_absolute_error: 0.8333
# Epoch 40/50
#  - 2s - loss: 15.1265 - mean_absolute_error: 3.0953 - val_loss: 2.7676 - val_mean_absolute_error: 1.5331
# Epoch 41/50
#  - 2s - loss: 11.3574 - mean_absolute_error: 2.8024 - val_loss: 39.4633 - val_mean_absolute_error: 6.2343
# Epoch 42/50
#  - 2s - loss: 7.4419 - mean_absolute_error: 2.1307 - val_loss: 9.4030 - val_mean_absolute_error: 2.9705
# Epoch 43/50
#  - 2s - loss: 5.1738 - mean_absolute_error: 1.8134 - val_loss: 27.4659 - val_mean_absolute_error: 5.1867
# Epoch 44/50
#  - 2s - loss: 3.9449 - mean_absolute_error: 1.5279 - val_loss: 6.7889 - val_mean_absolute_error: 2.4973
# Epoch 45/50
#  - 2s - loss: 2.7780 - mean_absolute_error: 1.3213 - val_loss: 0.7471 - val_mean_absolute_error: 0.7049
# Epoch 46/50
#  - 2s - loss: 1.9873 - mean_absolute_error: 1.1268 - val_loss: 0.7450 - val_mean_absolute_error: 0.6254
# Epoch 47/50
#  - 2s - loss: 1.5108 - mean_absolute_error: 0.9782 - val_loss: 0.7979 - val_mean_absolute_error: 0.7358
# Epoch 48/50
#  - 2s - loss: 1.0913 - mean_absolute_error: 0.8223 - val_loss: 0.4944 - val_mean_absolute_error: 0.5475
# Epoch 49/50
#  - 2s - loss: 0.8639 - mean_absolute_error: 0.7291 - val_loss: 0.4963 - val_mean_absolute_error: 0.5381
# Epoch 50/50
#  - 2s - loss: 0.7711 - mean_absolute_error: 0.6987 - val_loss: 0.5199 - val_mean_absolute_error: 0.5252

# %%
plt.plot(pred)
