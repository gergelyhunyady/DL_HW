# %% [markdown]
# DimensionPatch

# %%
import os   # for path operations
import datetime

import tensorflow as tf
from tensorflow.python.client import device_lib

import numpy as np
import pandas as pd
import sklearn as sk
from sklearn import preprocessing

from keras.models import Sequential
from keras.layers.core import Activation, Dense, Flatten
from keras.optimizers import SGD
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.backend.tensorflow_backend import set_session

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config))
# Device check
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 18287920353768915856
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3168377241
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16024526574593437673
# physical_device_desc: "device: 0, name: GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
# nb_input_series : time + 9 IMU data + optional prev. beta (min 10)
# nb_outputs : beta () or quvaternion representation) (min 1)

def make_1d_convnet(window_size, filter_length, nb_input_series=1, nb_outputs=1,nb_filter=4):
  model = Sequential()
  model.add(Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu', 
                   input_shape=(window_size,nb_input_series)))
  model.add(MaxPooling1D())
  model.add(Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu'))
  model.add(MaxPooling1D())
  model.add(Flatten())
  model.add(Dense(nb_outputs,activation='linear'))
  model.compile(loss='mse', optimizer='adam', metrics=['mae'])
  return model

# %%
def make_timeseries_instances(timeseries,window_size):
  timeseries = np.asarray(timeseries)
  assert 0 < window_size < timeseries.shape[0] , "Out of range 0 < {} < {}".format(window_size,timeseries.shape[0])
  X = np.atleast_3d(np.array([timeseries[start:start+window_size] for start in range(0,timeseries.shape[0]-window_size)]))
  y = timeseries[window_size:]
  return X,y

# %%
def evalute_timeseries(X, Y, window_size, filter_length, nb_filter, valid_split, test_split, patience, epochs, batch_size):
  early_stopping=EarlyStopping(patience=patience, verbose=1)
  checkpointer=ModelCheckpoint(filepath="weights_bazs.hdf5", save_best_only=True, verbose =1)

  nb_samples = X.shape[0]
  nb_series = X.shape[2]
  
  # Model definition (previously definied) 10 input chanel, 1 output chanel
  model= make_1d_convnet(window_size=window_size, filter_length=filter_length, nb_input_series=nb_series,
                        nb_outputs=1,nb_filter=nb_filter)
  model.summary()
    
  valid_size = int(nb_samples*(1-test_split-valid_split))
  test_size = int(nb_samples*(1-test_split))
  X_train, Y_train = X[:valid_size], Y[:valid_size]
  X_valid, Y_valid = X[valid_size:test_size], Y[valid_size:test_size]
  X_test, Y_test   = X[test_size:], Y[test_size:]
    
  model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_valid, Y_valid), verbose=2, callbacks = [checkpointer,early_stopping])
    
  preds=model.predict(X_test)
  targets = Y_test

  plt.plot(preds)
  plt.plot(targets)
  return preds, targets

# %% [markdown]
# # Load Data

# %%
lock_meas = '..\\DATA\\RAW\\Measure_02'
file_list = os.listdir(lock_meas)
nb_meas = len(file_list)/4
print("Number of Measurements: %0.f" % nb_meas)
# Out:
# Number of Measurements: 6

# %%
meas_list = []
for FILE_NAME in file_list:
    meas_list.append(FILE_NAME[0:22])
meas_list = list(set(meas_list))

# %%
# Load in one favourite measurement block
meas_id = 4
print(str(meas_list[meas_id]))

if meas_id>(nb_meas-1):
    print('Error: Out of range. Meas_id set to default 0')
    meas = 0
meas_date = str(meas_list[meas_id])

imu_data = pd.read_csv(lock_meas + '\\' + meas_date + 'IMU.txt',
                               sep='\t',
                               decimal=',',
                               names=['time', 'acc0', 'acc1', 'acc2', 'gyro0', 'gyro1', 'gyro2', 'mag0', 'mag1', 'mag2'])

mocap_data = pd.read_csv(lock_meas + '\\' + meas_date + 'MoCap.txt',
                                 sep='\t',
                                 decimal=',',
                                 names=['time', 'x', 'y', 'z', 'tracked', 'beta', 'Qx', 'Qy', 'Qz', 'Qw'])
# Out:
# 2018_ 10_ 19_18_21_28_

# %%
#imu_data.head(5)

# %%
#mocap_data.head(5)

# %%
data = pd.merge(imu_data, mocap_data, on=['time'], how='inner')
len(data)
# Out:
# 3123

# %%
data.head(2)
# Out:
#           time   acc0   acc1   acc2  gyro0  gyro1  gyro2   mag0   mag1   mag2  \
# 0  182127.6188 -0.001 -0.050  1.025 -0.765  0.222 -0.148 -0.373 -0.251  0.052
# 1  182127.6277 -0.001 -0.049  1.025 -1.108  0.181 -0.215 -0.376 -0.251  0.052
#
#        x      y      z  tracked    beta     Qx     Qy     Qz     Qw
# 0  0.725  0.212 -0.735      1.0  19.857  0.013 -0.172  0.003  0.985
# 1  0.725  0.212 -0.735      1.0  19.845  0.013 -0.172  0.003  0.985

# %%
f1, (ax1, ax2, ax3) = plt.subplots(3, 1)
data.plot(x='time', y='acc0', figsize=(15,10), ax=ax1)
data.plot(x='time', y='acc1', ax=ax1)
data.plot(x='time', y='acc2', ax=ax1)
data.plot(x='time', y='gyro0', ax=ax2)
data.plot(x='time', y='gyro1', ax=ax2)
data.plot(x='time', y='gyro2', ax=ax2)
data.plot(x='time', y='mag0', ax=ax3)
data.plot(x='time', y='mag1', ax=ax3)
data.plot(x='time', y='mag2', ax=ax3)

# %%
f2, (ax4, ax5, ax6, ax7) = plt.subplots(4, 1)
data.plot(x='time', y='x', figsize=(15,10), ax=ax4)
data.plot(x='time', y='y', ax=ax4)
data.plot(x='time', y='z', ax=ax4)
data.plot(x='time', y='tracked', ax=ax5)
data.plot(x='time', y='Qx', ax=ax6)
data.plot(x='time', y='Qy', ax=ax6)
data.plot(x='time', y='Qz', ax=ax6)
data.plot(x='time', y='Qw', ax=ax6)
data.plot(x='time', y='beta', ax=ax7)

# %%
data.plot(x='x', y='z', color='red', figsize=(15,15), label='MoCap')

# %%
#1D convolution
window_size = 20
filter_length = 5
nb_filter = 4

#Train config
epochs = 100
patience=50
batch_size = 16
vs = 0.15
ts = 0.15

# %%
data.head(1)
# Out:
#           time   acc0  acc1   acc2  gyro0  gyro1  gyro2   mag0   mag1   mag2  \
# 0  182127.6188 -0.001 -0.05  1.025 -0.765  0.222 -0.148 -0.373 -0.251  0.052
#
#        x      y      z  tracked    beta     Qx     Qy     Qz     Qw
# 0  0.725  0.212 -0.735      1.0  19.857  0.013 -0.172  0.003  0.985

# %%
Y = np.array(data['x'][window_size:])
X= np.array(data[list(data.columns[0:9])])

# %%
X = np.atleast_3d(np.array([X[start:start+window_size] for start in range(0,X.shape[0]-window_size)]))

# %%
pred, target = evalute_timeseries(X, Y, window_size,filter_length,nb_filter, vs, ts, patience, epochs, batch_size)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 16, 4)             184
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 8, 4)              0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 4, 4)              84
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 2, 4)              0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 277
# Trainable params: 277
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2172 samples, validate on 465 samples
# Epoch 1/100
#  - 2s - loss: 79289581.0437 - mean_absolute_error: 3931.4561 - val_loss: 0.4454 - val_mean_absolute_error: 0.6674
#
# Epoch 00001: val_loss improved from inf to 0.44544, saving model to weights_bazs.hdf5
# Epoch 2/100
#  - 1s - loss: 0.4486 - mean_absolute_error: 0.6696 - val_loss: 0.4454 - val_mean_absolute_error: 0.6673
#
# Epoch 00002: val_loss improved from 0.44544 to 0.44543, saving model to weights_bazs.hdf5
# Epoch 3/100
#  - 1s - loss: 0.4486 - mean_absolute_error: 0.6696 - val_loss: 0.4454 - val_mean_absolute_error: 0.6673
#
# Epoch 00003: val_loss improved from 0.44543 to 0.44540, saving model to weights_bazs.hdf5
# Epoch 4/100
#  - 1s - loss: 0.4486 - mean_absolute_error: 0.6696 - val_loss: 0.4454 - val_mean_absolute_error: 0.6673
#
# Epoch 00004: val_loss improved from 0.44540 to 0.44537, saving model to weights_bazs.hdf5
# Epoch 5/100
#  - 1s - loss: 0.4486 - mean_absolute_error: 0.6696 - val_loss: 0.4453 - val_mean_absolute_error: 0.6673
#
# Epoch 00005: val_loss improved from 0.44537 to 0.44534, saving model to weights_bazs.hdf5
# Epoch 6/100
#  - 1s - loss: 0.4485 - mean_absolute_error: 0.6695 - val_loss: 0.4453 - val_mean_absolute_error: 0.6672
#
# Epoch 00006: val_loss improved from 0.44534 to 0.44530, saving model to weights_bazs.hdf5
# Epoch 7/100
#  - 1s - loss: 0.4485 - mean_absolute_error: 0.6695 - val_loss: 0.4453 - val_mean_absolute_error: 0.6672
#
# Epoch 00007: val_loss improved from 0.44530 to 0.44526, saving model to weights_bazs.hdf5
# Epoch 8/100
#  - 1s - loss: 0.4484 - mean_absolute_error: 0.6695 - val_loss: 0.4452 - val_mean_absolute_error: 0.6672
#
# Epoch 00008: val_loss improved from 0.44526 to 0.44521, saving model to weights_bazs.hdf5
# Epoch 9/100
#  - 1s - loss: 0.4484 - mean_absolute_error: 0.6694 - val_loss: 0.4452 - val_mean_absolute_error: 0.6671
#
# Epoch 00009: val_loss improved from 0.44521 to 0.44515, saving model to weights_bazs.hdf5
# Epoch 10/100
#  - 1s - loss: 0.4483 - mean_absolute_error: 0.6694 - val_loss: 0.4451 - val_mean_absolute_error: 0.6671
#
# Epoch 00010: val_loss improved from 0.44515 to 0.44509, saving model to weights_bazs.hdf5
# Epoch 11/100
#  - 1s - loss: 0.4483 - mean_absolute_error: 0.6694 - val_loss: 0.4450 - val_mean_absolute_error: 0.6670
#
# Epoch 00011: val_loss improved from 0.44509 to 0.44503, saving model to weights_bazs.hdf5
# Epoch 12/100
#  - 0s - loss: 0.4482 - mean_absolute_error: 0.6693 - val_loss: 0.4450 - val_mean_absolute_error: 0.6670
#
# Epoch 00012: val_loss improved from 0.44503 to 0.44496, saving model to weights_bazs.hdf5
# Epoch 13/100
#  - 1s - loss: 0.4481 - mean_absolute_error: 0.6692 - val_loss: 0.4449 - val_mean_absolute_error: 0.6669
#
# Epoch 00013: val_loss improved from 0.44496 to 0.44488, saving model to weights_bazs.hdf5
# Epoch 14/100
#  - 1s - loss: 0.4480 - mean_absolute_error: 0.6692 - val_loss: 0.4448 - val_mean_absolute_error: 0.6669
#
# Epoch 00014: val_loss improved from 0.44488 to 0.44479, saving model to weights_bazs.hdf5
# Epoch 15/100
#  - 1s - loss: 0.4480 - mean_absolute_error: 0.6691 - val_loss: 0.4447 - val_mean_absolute_error: 0.6668
#
# Epoch 00015: val_loss improved from 0.44479 to 0.44470, saving model to weights_bazs.hdf5
# Epoch 16/100
#  - 1s - loss: 0.4479 - mean_absolute_error: 0.6690 - val_loss: 0.4446 - val_mean_absolute_error: 0.6667
#
# Epoch 00016: val_loss improved from 0.44470 to 0.44460, saving model to weights_bazs.hdf5
# Epoch 17/100
#  - 1s - loss: 0.4478 - mean_absolute_error: 0.6690 - val_loss: 0.4445 - val_mean_absolute_error: 0.6666
#
# Epoch 00017: val_loss improved from 0.44460 to 0.44450, saving model to weights_bazs.hdf5
# Epoch 18/100
#  - 1s - loss: 0.4476 - mean_absolute_error: 0.6689 - val_loss: 0.4444 - val_mean_absolute_error: 0.6666
#
# Epoch 00018: val_loss improved from 0.44450 to 0.44438, saving model to weights_bazs.hdf5
# Epoch 19/100
#  - 1s - loss: 0.4475 - mean_absolute_error: 0.6688 - val_loss: 0.4443 - val_mean_absolute_error: 0.6665
#
# Epoch 00019: val_loss improved from 0.44438 to 0.44426, saving model to weights_bazs.hdf5
# Epoch 20/100
#  - 1s - loss: 0.4474 - mean_absolute_error: 0.6687 - val_loss: 0.4441 - val_mean_absolute_error: 0.6664
#
# Epoch 00020: val_loss improved from 0.44426 to 0.44412, saving model to weights_bazs.hdf5
# Epoch 21/100
#  - 1s - loss: 0.4473 - mean_absolute_error: 0.6686 - val_loss: 0.4440 - val_mean_absolute_error: 0.6663
#
# Epoch 00021: val_loss improved from 0.44412 to 0.44398, saving model to weights_bazs.hdf5
# Epoch 22/100
#  - 1s - loss: 0.4471 - mean_absolute_error: 0.6685 - val_loss: 0.4438 - val_mean_absolute_error: 0.6661
#
# Epoch 00022: val_loss improved from 0.44398 to 0.44382, saving model to weights_bazs.hdf5
# Epoch 23/100
#  - 1s - loss: 0.4469 - mean_absolute_error: 0.6684 - val_loss: 0.4437 - val_mean_absolute_error: 0.6660
#
# Epoch 00023: val_loss improved from 0.44382 to 0.44366, saving model to weights_bazs.hdf5
# Epoch 24/100
#  - 1s - loss: 0.4468 - mean_absolute_error: 0.6682 - val_loss: 0.4435 - val_mean_absolute_error: 0.6659
#
# Epoch 00024: val_loss improved from 0.44366 to 0.44348, saving model to weights_bazs.hdf5
# Epoch 25/100
#  - 1s - loss: 0.4466 - mean_absolute_error: 0.6681 - val_loss: 0.4433 - val_mean_absolute_error: 0.6657
#
# Epoch 00025: val_loss improved from 0.44348 to 0.44329, saving model to weights_bazs.hdf5
# Epoch 26/100
#  - 1s - loss: 0.4464 - mean_absolute_error: 0.6679 - val_loss: 0.4431 - val_mean_absolute_error: 0.6656
#
# Epoch 00026: val_loss improved from 0.44329 to 0.44308, saving model to weights_bazs.hdf5
# Epoch 27/100
#  - 1s - loss: 0.4462 - mean_absolute_error: 0.6678 - val_loss: 0.4429 - val_mean_absolute_error: 0.6654
#
# Epoch 00027: val_loss improved from 0.44308 to 0.44287, saving model to weights_bazs.hdf5
# Epoch 28/100
#  - 1s - loss: 0.4459 - mean_absolute_error: 0.6676 - val_loss: 0.4426 - val_mean_absolute_error: 0.6652
#
# Epoch 00028: val_loss improved from 0.44287 to 0.44263, saving model to weights_bazs.hdf5
# Epoch 29/100
#  - 1s - loss: 0.4457 - mean_absolute_error: 0.6674 - val_loss: 0.4424 - val_mean_absolute_error: 0.6651
#
# Epoch 00029: val_loss improved from 0.44263 to 0.44238, saving model to weights_bazs.hdf5
# Epoch 30/100
#  - 1s - loss: 0.4454 - mean_absolute_error: 0.6672 - val_loss: 0.4421 - val_mean_absolute_error: 0.6648
#
# Epoch 00030: val_loss improved from 0.44238 to 0.44211, saving model to weights_bazs.hdf5
# Epoch 31/100
#  - 1s - loss: 0.4452 - mean_absolute_error: 0.6670 - val_loss: 0.4418 - val_mean_absolute_error: 0.6646
#
# Epoch 00031: val_loss improved from 0.44211 to 0.44182, saving model to weights_bazs.hdf5
# Epoch 32/100
#  - 1s - loss: 0.4449 - mean_absolute_error: 0.6668 - val_loss: 0.4415 - val_mean_absolute_error: 0.6644
#
# Epoch 00032: val_loss improved from 0.44182 to 0.44151, saving model to weights_bazs.hdf5
# Epoch 33/100
#  - 1s - loss: 0.4445 - mean_absolute_error: 0.6666 - val_loss: 0.4412 - val_mean_absolute_error: 0.6641
#
# Epoch 00033: val_loss improved from 0.44151 to 0.44118, saving model to weights_bazs.hdf5
# Epoch 34/100
#  - 1s - loss: 0.4442 - mean_absolute_error: 0.6663 - val_loss: 0.4408 - val_mean_absolute_error: 0.6639
#
# Epoch 00034: val_loss improved from 0.44118 to 0.44082, saving model to weights_bazs.hdf5
# Epoch 35/100
#  - 1s - loss: 0.4438 - mean_absolute_error: 0.6660 - val_loss: 0.4404 - val_mean_absolute_error: 0.6636
#
# Epoch 00035: val_loss improved from 0.44082 to 0.44044, saving model to weights_bazs.hdf5
# Epoch 36/100
#  - 1s - loss: 0.4434 - mean_absolute_error: 0.6657 - val_loss: 0.4400 - val_mean_absolute_error: 0.6633
#
# Epoch 00036: val_loss improved from 0.44044 to 0.44004, saving model to weights_bazs.hdf5
# Epoch 37/100
#  - 1s - loss: 0.4430 - mean_absolute_error: 0.6654 - val_loss: 0.4396 - val_mean_absolute_error: 0.6630
#
# Epoch 00037: val_loss improved from 0.44004 to 0.43960, saving model to weights_bazs.hdf5
# Epoch 38/100
#  - 1s - loss: 0.4426 - mean_absolute_error: 0.6651 - val_loss: 0.4391 - val_mean_absolute_error: 0.6626
#
# Epoch 00038: val_loss improved from 0.43960 to 0.43913, saving model to weights_bazs.hdf5
# Epoch 39/100
#  - 1s - loss: 0.4421 - mean_absolute_error: 0.6647 - val_loss: 0.4386 - val_mean_absolute_error: 0.6622
#
# Epoch 00039: val_loss improved from 0.43913 to 0.43864, saving model to weights_bazs.hdf5
# Epoch 40/100
#  - 1s - loss: 0.4416 - mean_absolute_error: 0.6643 - val_loss: 0.4381 - val_mean_absolute_error: 0.6618
#
# Epoch 00040: val_loss improved from 0.43864 to 0.43810, saving model to weights_bazs.hdf5
# Epoch 41/100
#  - 1s - loss: 0.4410 - mean_absolute_error: 0.6639 - val_loss: 0.4375 - val_mean_absolute_error: 0.6614
#
# Epoch 00041: val_loss improved from 0.43810 to 0.43754, saving model to weights_bazs.hdf5
# Epoch 42/100
#  - 1s - loss: 0.4404 - mean_absolute_error: 0.6635 - val_loss: 0.4369 - val_mean_absolute_error: 0.6609
#
# Epoch 00042: val_loss improved from 0.43754 to 0.43693, saving model to weights_bazs.hdf5
# Epoch 43/100
#  - 1s - loss: 0.4398 - mean_absolute_error: 0.6630 - val_loss: 0.4363 - val_mean_absolute_error: 0.6604
#
# Epoch 00043: val_loss improved from 0.43693 to 0.43628, saving model to weights_bazs.hdf5
# Epoch 44/100
#  - 1s - loss: 0.4391 - mean_absolute_error: 0.6625 - val_loss: 0.4356 - val_mean_absolute_error: 0.6599
#
# Epoch 00044: val_loss improved from 0.43628 to 0.43558, saving model to weights_bazs.hdf5
# Epoch 45/100
#  - 1s - loss: 0.4384 - mean_absolute_error: 0.6619 - val_loss: 0.4348 - val_mean_absolute_error: 0.6594
#
# Epoch 00045: val_loss improved from 0.43558 to 0.43484, saving model to weights_bazs.hdf5
# Epoch 46/100
#  - 1s - loss: 0.4376 - mean_absolute_error: 0.6613 - val_loss: 0.4340 - val_mean_absolute_error: 0.6588
#
# Epoch 00046: val_loss improved from 0.43484 to 0.43404, saving model to weights_bazs.hdf5
# Epoch 47/100
#  - 1s - loss: 0.4368 - mean_absolute_error: 0.6607 - val_loss: 0.4332 - val_mean_absolute_error: 0.6581
#
# Epoch 00047: val_loss improved from 0.43404 to 0.43319, saving model to weights_bazs.hdf5
# Epoch 48/100
#  - 1s - loss: 0.4359 - mean_absolute_error: 0.6601 - val_loss: 0.4323 - val_mean_absolute_error: 0.6574
#
# Epoch 00048: val_loss improved from 0.43319 to 0.43229, saving model to weights_bazs.hdf5
# Epoch 49/100
#  - 1s - loss: 0.4350 - mean_absolute_error: 0.6593 - val_loss: 0.4313 - val_mean_absolute_error: 0.6567
#
# Epoch 00049: val_loss improved from 0.43229 to 0.43132, saving model to weights_bazs.hdf5
# Epoch 50/100
#  - 1s - loss: 0.4340 - mean_absolute_error: 0.6586 - val_loss: 0.4303 - val_mean_absolute_error: 0.6559
#
# Epoch 00050: val_loss improved from 0.43132 to 0.43028, saving model to weights_bazs.hdf5
# Epoch 51/100
#  - 1s - loss: 0.4329 - mean_absolute_error: 0.6578 - val_loss: 0.4292 - val_mean_absolute_error: 0.6551
#
# Epoch 00051: val_loss improved from 0.43028 to 0.42918, saving model to weights_bazs.hdf5
# Epoch 52/100
#  - 1s - loss: 0.4317 - mean_absolute_error: 0.6569 - val_loss: 0.4280 - val_mean_absolute_error: 0.6542
#
# Epoch 00052: val_loss improved from 0.42918 to 0.42800, saving model to weights_bazs.hdf5
# Epoch 53/100
#  - 1s - loss: 0.4305 - mean_absolute_error: 0.6560 - val_loss: 0.4267 - val_mean_absolute_error: 0.6532
#
# Epoch 00053: val_loss improved from 0.42800 to 0.42674, saving model to weights_bazs.hdf5
# Epoch 54/100
#  - 1s - loss: 0.4292 - mean_absolute_error: 0.6550 - val_loss: 0.4254 - val_mean_absolute_error: 0.6522
#
# Epoch 00054: val_loss improved from 0.42674 to 0.42539, saving model to weights_bazs.hdf5
# Epoch 55/100
#  - 1s - loss: 0.4278 - mean_absolute_error: 0.6539 - val_loss: 0.4240 - val_mean_absolute_error: 0.6511
#
# Epoch 00055: val_loss improved from 0.42539 to 0.42396, saving model to weights_bazs.hdf5
# Epoch 56/100
#  - 1s - loss: 0.4263 - mean_absolute_error: 0.6528 - val_loss: 0.4224 - val_mean_absolute_error: 0.6499
#
# Epoch 00056: val_loss improved from 0.42396 to 0.42243, saving model to weights_bazs.hdf5
# Epoch 57/100
#  - 1s - loss: 0.4248 - mean_absolute_error: 0.6515 - val_loss: 0.4208 - val_mean_absolute_error: 0.6486
#
# Epoch 00057: val_loss improved from 0.42243 to 0.42080, saving model to weights_bazs.hdf5
# Epoch 58/100
#  - 1s - loss: 0.4231 - mean_absolute_error: 0.6503 - val_loss: 0.4191 - val_mean_absolute_error: 0.6473
#
# Epoch 00058: val_loss improved from 0.42080 to 0.41906, saving model to weights_bazs.hdf5
# Epoch 59/100
#  - 1s - loss: 0.4213 - mean_absolute_error: 0.6489 - val_loss: 0.4172 - val_mean_absolute_error: 0.6458
#
# Epoch 00059: val_loss improved from 0.41906 to 0.41720, saving model to weights_bazs.hdf5
# Epoch 60/100
#  - 1s - loss: 0.4193 - mean_absolute_error: 0.6474 - val_loss: 0.4152 - val_mean_absolute_error: 0.6443
#
# Epoch 00060: val_loss improved from 0.41720 to 0.41523, saving model to weights_bazs.hdf5
# Epoch 61/100
#  - 1s - loss: 0.4173 - mean_absolute_error: 0.6458 - val_loss: 0.4131 - val_mean_absolute_error: 0.6427
#
# Epoch 00061: val_loss improved from 0.41523 to 0.41312, saving model to weights_bazs.hdf5
# Epoch 62/100
#  - 1s - loss: 0.4151 - mean_absolute_error: 0.6441 - val_loss: 0.4109 - val_mean_absolute_error: 0.6409
#
# Epoch 00062: val_loss improved from 0.41312 to 0.41088, saving model to weights_bazs.hdf5
# Epoch 63/100
#  - 1s - loss: 0.4128 - mean_absolute_error: 0.6423 - val_loss: 0.4085 - val_mean_absolute_error: 0.6391
#
# Epoch 00063: val_loss improved from 0.41088 to 0.40850, saving model to weights_bazs.hdf5
# Epoch 64/100
#  - 1s - loss: 0.4103 - mean_absolute_error: 0.6404 - val_loss: 0.4060 - val_mean_absolute_error: 0.6371
#
# Epoch 00064: val_loss improved from 0.40850 to 0.40596, saving model to weights_bazs.hdf5
# Epoch 65/100
#  - 1s - loss: 0.4077 - mean_absolute_error: 0.6383 - val_loss: 0.4033 - val_mean_absolute_error: 0.6350
#
# Epoch 00065: val_loss improved from 0.40596 to 0.40326, saving model to weights_bazs.hdf5
# Epoch 66/100
#  - 1s - loss: 0.4049 - mean_absolute_error: 0.6361 - val_loss: 0.4004 - val_mean_absolute_error: 0.6327
#
# Epoch 00066: val_loss improved from 0.40326 to 0.40039, saving model to weights_bazs.hdf5
# Epoch 67/100
#  - 1s - loss: 0.4019 - mean_absolute_error: 0.6338 - val_loss: 0.3973 - val_mean_absolute_error: 0.6303
#
# Epoch 00067: val_loss improved from 0.40039 to 0.39735, saving model to weights_bazs.hdf5
# Epoch 68/100
#  - 1s - loss: 0.3988 - mean_absolute_error: 0.6313 - val_loss: 0.3941 - val_mean_absolute_error: 0.6277
#
# Epoch 00068: val_loss improved from 0.39735 to 0.39411, saving model to weights_bazs.hdf5
# Epoch 69/100
#  - 1s - loss: 0.3954 - mean_absolute_error: 0.6287 - val_loss: 0.3907 - val_mean_absolute_error: 0.6250
#
# Epoch 00069: val_loss improved from 0.39411 to 0.39067, saving model to weights_bazs.hdf5
# Epoch 70/100
#  - 1s - loss: 0.3919 - mean_absolute_error: 0.6258 - val_loss: 0.3870 - val_mean_absolute_error: 0.6220
#
# Epoch 00070: val_loss improved from 0.39067 to 0.38703, saving model to weights_bazs.hdf5
# Epoch 71/100
#  - 1s - loss: 0.3881 - mean_absolute_error: 0.6228 - val_loss: 0.3832 - val_mean_absolute_error: 0.6189
#
# Epoch 00071: val_loss improved from 0.38703 to 0.38316, saving model to weights_bazs.hdf5
# Epoch 72/100
#  - 1s - loss: 0.3841 - mean_absolute_error: 0.6196 - val_loss: 0.3791 - val_mean_absolute_error: 0.6156
#
# Epoch 00072: val_loss improved from 0.38316 to 0.37907, saving model to weights_bazs.hdf5
# Epoch 73/100
#  - 1s - loss: 0.3799 - mean_absolute_error: 0.6162 - val_loss: 0.3747 - val_mean_absolute_error: 0.6121
#
# Epoch 00073: val_loss improved from 0.37907 to 0.37474, saving model to weights_bazs.hdf5
# Epoch 74/100
#  - 1s - loss: 0.3754 - mean_absolute_error: 0.6125 - val_loss: 0.3702 - val_mean_absolute_error: 0.6083
# Epoch 00074: val_loss improved from 0.37474 to 0.37015, saving model to weights_bazs.hdf5
# Epoch 75/100
#  - 1s - loss: 0.3707 - mean_absolute_error: 0.6087 - val_loss: 0.3653 - val_mean_absolute_error: 0.6043
#
# Epoch 00075: val_loss improved from 0.37015 to 0.36531, saving model to weights_bazs.hdf5
# Epoch 76/100
#  - 1s - loss: 0.3657 - mean_absolute_error: 0.6045 - val_loss: 0.3602 - val_mean_absolute_error: 0.6001
#
# Epoch 00076: val_loss improved from 0.36531 to 0.36020, saving model to weights_bazs.hdf5
# Epoch 77/100
#  - 1s - loss: 0.3604 - mean_absolute_error: 0.6002 - val_loss: 0.3548 - val_mean_absolute_error: 0.5956
#
# Epoch 00077: val_loss improved from 0.36020 to 0.35480, saving model to weights_bazs.hdf5
# Epoch 78/100
#  - 1s - loss: 0.3549 - mean_absolute_error: 0.5955 - val_loss: 0.3491 - val_mean_absolute_error: 0.5908
#
# Epoch 00078: val_loss improved from 0.35480 to 0.34912, saving model to weights_bazs.hdf5
# Epoch 79/100
#  - 1s - loss: 0.3490 - mean_absolute_error: 0.5906 - val_loss: 0.3431 - val_mean_absolute_error: 0.5857
#
# Epoch 00079: val_loss improved from 0.34912 to 0.34313, saving model to weights_bazs.hdf5
# Epoch 80/100
#  - 1s - loss: 0.3429 - mean_absolute_error: 0.5853 - val_loss: 0.3368 - val_mean_absolute_error: 0.5803
#
# Epoch 00080: val_loss improved from 0.34313 to 0.33684, saving model to weights_bazs.hdf5
# Epoch 81/100
#  - 1s - loss: 0.3364 - mean_absolute_error: 0.5798 - val_loss: 0.3302 - val_mean_absolute_error: 0.5746
#
# Epoch 00081: val_loss improved from 0.33684 to 0.33023, saving model to weights_bazs.hdf5
# Epoch 82/100
#  - 1s - loss: 0.3296 - mean_absolute_error: 0.5739 - val_loss: 0.3233 - val_mean_absolute_error: 0.5685
#
# Epoch 00082: val_loss improved from 0.33023 to 0.32330, saving model to weights_bazs.hdf5
# Epoch 83/100
#  - 1s - loss: 0.3225 - mean_absolute_error: 0.5677 - val_loss: 0.3160 - val_mean_absolute_error: 0.5621
#
# Epoch 00083: val_loss improved from 0.32330 to 0.31605, saving model to weights_bazs.hdf5
# Epoch 84/100
#  - 1s - loss: 0.3150 - mean_absolute_error: 0.5611 - val_loss: 0.3085 - val_mean_absolute_error: 0.5553
#
# Epoch 00084: val_loss improved from 0.31605 to 0.30847, saving model to weights_bazs.hdf5
# Epoch 85/100
#  - 1s - loss: 0.3072 - mean_absolute_error: 0.5541 - val_loss: 0.3005 - val_mean_absolute_error: 0.5481
#
# Epoch 00085: val_loss improved from 0.30847 to 0.30055, saving model to weights_bazs.hdf5
# Epoch 86/100
#  - 0s - loss: 0.2991 - mean_absolute_error: 0.5467 - val_loss: 0.2923 - val_mean_absolute_error: 0.5406
#
# Epoch 00086: val_loss improved from 0.30055 to 0.29230, saving model to weights_bazs.hdf5
# Epoch 87/100
#  - 1s - loss: 0.2907 - mean_absolute_error: 0.5389 - val_loss: 0.2837 - val_mean_absolute_error: 0.5326
#
# Epoch 00087: val_loss improved from 0.29230 to 0.28372, saving model to weights_bazs.hdf5
# Epoch 88/100
#  - 1s - loss: 0.2819 - mean_absolute_error: 0.5307 - val_loss: 0.2748 - val_mean_absolute_error: 0.5242
#
# Epoch 00088: val_loss improved from 0.28372 to 0.27482, saving model to weights_bazs.hdf5
# Epoch 89/100
#  - 1s - loss: 0.2728 - mean_absolute_error: 0.5221 - val_loss: 0.2656 - val_mean_absolute_error: 0.5153
#
# Epoch 00089: val_loss improved from 0.27482 to 0.26560, saving model to weights_bazs.hdf5
# Epoch 90/100
#  - 0s - loss: 0.2634 - mean_absolute_error: 0.5130 - val_loss: 0.2561 - val_mean_absolute_error: 0.5060
#
# Epoch 00090: val_loss improved from 0.26560 to 0.25608, saving model to weights_bazs.hdf5
# Epoch 91/100
#  - 1s - loss: 0.2537 - mean_absolute_error: 0.5034 - val_loss: 0.2463 - val_mean_absolute_error: 0.4962
#
# Epoch 00091: val_loss improved from 0.25608 to 0.24627, saving model to weights_bazs.hdf5
# Epoch 92/100
#  - 0s - loss: 0.2437 - mean_absolute_error: 0.4934 - val_loss: 0.2362 - val_mean_absolute_error: 0.4859
#
# Epoch 00092: val_loss improved from 0.24627 to 0.23618, saving model to weights_bazs.hdf5
# Epoch 93/100
#  - 0s - loss: 0.2334 - mean_absolute_error: 0.4829 - val_loss: 0.2258 - val_mean_absolute_error: 0.4751
#
# Epoch 00093: val_loss improved from 0.23618 to 0.22585, saving model to weights_bazs.hdf5
# Epoch 94/100
#  - 0s - loss: 0.2229 - mean_absolute_error: 0.4719 - val_loss: 0.2153 - val_mean_absolute_error: 0.4639
#
# Epoch 00094: val_loss improved from 0.22585 to 0.21529, saving model to weights_bazs.hdf5
# Epoch 95/100
#  - 1s - loss: 0.2122 - mean_absolute_error: 0.4604 - val_loss: 0.2045 - val_mean_absolute_error: 0.4522
#
# Epoch 00095: val_loss improved from 0.21529 to 0.20453, saving model to weights_bazs.hdf5
# Epoch 96/100
#  - 0s - loss: 0.2013 - mean_absolute_error: 0.4484 - val_loss: 0.1936 - val_mean_absolute_error: 0.4399
#
# Epoch 00096: val_loss improved from 0.20453 to 0.19362, saving model to weights_bazs.hdf5
# Epoch 97/100
#  - 0s - loss: 0.1903 - mean_absolute_error: 0.4359 - val_loss: 0.1826 - val_mean_absolute_error: 0.4272
#
# Epoch 00097: val_loss improved from 0.19362 to 0.18258, saving model to weights_bazs.hdf5
# Epoch 98/100
#  - 1s - loss: 0.1792 - mean_absolute_error: 0.4230 - val_loss: 0.1715 - val_mean_absolute_error: 0.4140
#
# Epoch 00098: val_loss improved from 0.18258 to 0.17147, saving model to weights_bazs.hdf5
# Epoch 99/100
#  - 1s - loss: 0.1680 - mean_absolute_error: 0.4095 - val_loss: 0.1603 - val_mean_absolute_error: 0.4003
#
# Epoch 00099: val_loss improved from 0.17147 to 0.16033, saving model to weights_bazs.hdf5
# Epoch 100/100
#  - 1s - loss: 0.1568 - mean_absolute_error: 0.3956 - val_loss: 0.1492 - val_mean_absolute_error: 0.3862
#
# Epoch 00100: val_loss improved from 0.16033 to 0.14921, saving model to weights_bazs.hdf5

# %%
plt.plot(pred)
