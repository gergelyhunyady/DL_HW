# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data (preprocess)

# %%
lock_meas = '..\\..\\DATA\\RAW\\Measure_02'
file_list = os.listdir(lock_meas)
nb_meas = len(file_list)/4

meas_list = []
for FILE_NAME in file_list:
    meas_list.append(FILE_NAME[0:22])
meas_list = list(set(meas_list))

# Load in one favourite measurement block
meas_id = 4

# Syncronise the measurement files from MoCap and IMU
if meas_id>(nb_meas-1):
    meas = 0
meas_date = str(meas_list[meas_id])

imu_data = pd.read_csv(lock_meas + '\\' + meas_date + 'IMU.txt',
                               sep='\t',
                               decimal=',',
                               names=['time', 'acc0', 'acc1', 'acc2', 'gyro0', 'gyro1', 'gyro2', 'mag0', 'mag1', 'mag2'])

mocap_data = pd.read_csv(lock_meas + '\\' + meas_date + 'MoCap.txt',
                                 sep='\t',
                                 decimal=',',
                                 names=['time', 'x', 'y', 'z', 'tracked', 'beta', 'Qx', 'Qy', 'Qz', 'Qw'])

data = pd.merge(imu_data, mocap_data, on=['time'], how='inner')

# Filter
df = data[~(data[['mag0','mag1','mag2','tracked']] == 0).any(axis=1)]

# %% [markdown]
# # Statistics

# %%
df.head(10)
# Out:
#           time   acc0   acc1   acc2  gyro0  gyro1  gyro2   mag0   mag1   mag2  \
# 0  180614.4063  0.005 -0.052  1.025 -0.745  0.201 -0.121  0.000  0.000  0.000
# 1  180614.4153  0.006 -0.052  1.025 -0.786  0.322 -0.215  0.000  0.000  0.000
# 2  180614.4243  0.005 -0.052  1.026 -0.705  0.121  0.013 -0.333 -0.282  0.048
# 3  180614.4332  0.005 -0.051  1.026 -0.967  0.000 -0.134 -0.333 -0.282  0.048
# 4  180614.4422  0.004 -0.051  1.026 -0.806  0.262  0.121 -0.333 -0.282  0.048
# 5  180614.4512  0.005 -0.052  1.026 -0.886  0.544 -0.081  0.000  0.000  0.000
# 6  180614.4602  0.005 -0.052  1.026 -0.705  0.181  0.054  0.000  0.000  0.000
# 7  180614.4701  0.005 -0.051  1.026 -0.947  0.201 -0.067 -0.330 -0.282  0.052
# 8  180614.4801  0.005 -0.051  1.026 -1.108  0.181  0.107 -0.333 -0.282  0.048
# 9  180614.4891  0.005 -0.051  1.026 -0.927  0.262 -0.081  0.000  0.000  0.000
#
#        x      y      z  tracked   beta     Qx     Qy     Qz   Qw
# 0 -0.485  0.222 -0.468      1.0  2.877  0.014 -0.025  0.005  1.0
# 1 -0.485  0.222 -0.468      1.0  2.874  0.014 -0.025  0.005  1.0
# 2 -0.485  0.222 -0.468      1.0  2.868  0.014 -0.025  0.005  1.0
# 3 -0.485  0.222 -0.468      1.0  2.866  0.014 -0.025  0.005  1.0
# 4 -0.485  0.222 -0.468      1.0  2.869  0.014 -0.025  0.005  1.0
# 5 -0.485  0.222 -0.468      1.0  2.856  0.014 -0.025  0.005  1.0
# 6 -0.485  0.222 -0.468      1.0  2.867  0.014 -0.025  0.005  1.0
# 7 -0.485  0.222 -0.468      1.0  2.865  0.014 -0.025  0.005  1.0
# 8 -0.485  0.222 -0.468      1.0  2.865  0.014 -0.025  0.005  1.0
# 9 -0.485  0.222 -0.468      1.0  2.848  0.014 -0.025  0.005  1.0

# %%
len(df)
# Out:
# 6234

# %% [markdown]
# # Graphs

# %%
df.plot(x='x', y='z', color='red', figsize=(8,8), label='MoCap')

# %%
f1, (ax1, ax2, ax3) = plt.subplots(3, 1)
df.plot(x='time', y='acc0', figsize=(15,10), ax=ax1)
df.plot(x='time', y='acc1', ax=ax1)
df.plot(x='time', y='acc2', ax=ax1)
df.plot(x='time', y='gyro0', ax=ax2)
df.plot(x='time', y='gyro1', ax=ax2)
df.plot(x='time', y='gyro2', ax=ax2)
df.plot(x='time', y='mag0', ax=ax3)
df.plot(x='time', y='mag1', ax=ax3)
df.plot(x='time', y='mag2', ax=ax3)

# %%
f2, (ax4, ax5, ax6, ax7) = plt.subplots(4, 1)
df.plot(x='time', y='x', figsize=(15,10), ax=ax4)
df.plot(x='time', y='y', ax=ax4)
df.plot(x='time', y='z', ax=ax4)
df.plot(x='time', y='tracked', ax=ax5)
df.plot(x='time', y='Qx', ax=ax6)
df.plot(x='time', y='Qy', ax=ax6)
df.plot(x='time', y='Qz', ax=ax6)
df.plot(x='time', y='Qw', ax=ax6)
df.plot(x='time', y='beta', ax=ax7)
